# %% [markdown]
# <a href="https://colab.research.google.com/github/SafayetHS/SafayetHS/blob/main/Summer_202dawdadawd2_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#OOP Class 1
#Design
class Student:
    def __init__(self):
        self.name = "XYZ"
        self.ID = 12345
        self.dept = "CSE"
        self.cg = 3.99
        
#Driver code
s1 = Student() #Object creation and initialization
print(s1)#Hexadecimal address where the object is created will be printed.
print(s1.name,s1.ID,s1.dept,s1.cg)#Before changing
s1.name  = "Sakib Al Hasan"
s1.ID = 9867
print(s1.name,s1.ID,s1.dept,s1.cg)#After changing name and ID.

s2 = Student()#Object creation and initialization
print(s2.name,s2.ID,s2.dept,s2.cg)

#The object referred by s2 is diffrenet from the object referred by s1.
#So changing the variables of the object referred to by s2 will have
#no effect on s1 and vise versa.
s2.name = "Tamim Iqbal"
s2.ID = 45678
print(s2.name,s2.ID,s2.dept,s2.cg)
#changing the name and ID of the object referred by s2 has no effect on
#the variables of the object referred by s1.
print(s1.name,s1.ID,s1.dept,s1.cg)

#If we create another object whose location will be referred by s1,
#the reference to the previous object referred to by s1 will be lost.
#The previous object referred to by s1 will be removed from memory.
#Now s1 will refer to the newly created object.
#Please uncomment the lines for testing
#s1 = Student()
#print(s1.name,s1.ID,s1.dept,s1.cg)

#if we write s1 = s2 then s1 and s2 both will refer to the same object.
#the reference to the previous object referred to by s1 will be lost.
#The previous object referred to by s1 will be removed from memory.
#Please uncomment the lines for testing
#s1 = s2
#print(s1.name,s1.ID,s1.dept,s1.cg)
#print(s2.name,s2.ID,s2.dept,s2.cg)
#s1.name = "Imrul Kayes"
#print(s1.name,s1.ID,s1.dept,s1.cg)
#print(s2.name,s2.ID,s2.dept,s2.cg)
#As you can see, the changing the value of s1.name changed the value
#of both s1.name and s2.name because they both refer to the same object.
# Out:
# ...
# XYZ 12345 CSE 3.99
# Sakib Al Hasan 9867 CSE 3.99
# XYZ 12345 CSE 3.99
# Tamim Iqbal 45678 CSE 3.99
# Sakib Al Hasan 9867 CSE 3.99

# %%
#OOP Class 2
#Design
class Student:
    def __init__(self,n,i,d,c):
      #Instance variables
        self.name = n
        self.ID = i
        self.dept = d
        self.cg = c
    def printDetails(self): #self will receive the address of  the object referred to by s1 or s2 depending which one you are using to call the method 
      print(f"Name:{self.name}")
      print(f"ID:{self.ID}")
      print(f"Department:{self.dept}")
      print(f"CGPA:{self.cg}")

s1 = Student("Bob",18301120,"CSE",3.97) #Passing arguments to init method instead of setting hardcoded values
s2 = Student("Alice",19023103,"CS",3.78) #Passing arguments to init method instead of setting hardcoded values

s1.printDetails() #Calling printDetails method to print the values of the instance variables of the object referred to by s1
print("-----------------------------------")
s2.printDetails() #Calling printDetails method to print the values of the instance variables of the object referred to by s2
# Out:
# Name:Bob
# ID:18301120
# Department:CSE
# CGPA:3.97
# -----------------------------------
# Name:Alice
# ID:19023103
# Department:CS
# CGPA:3.78

# %%
#OOP Class 3
#Example 1
class Account:
  def __init__(self,ac_no,ac_name,balance):
    self.acc_no = ac_no
    self.acc_name = ac_name
    self.balance = balance
  def printDetails(self):
    print(f"Accountaprint(f"Account Name:{self.acc_name}")
    print(f"Current balance:{self.balance} tk")
  def deposit(self,amount):
    self.balance += amount
    self.printDetails()
  def withdraw(self,amount):
    if self.balance-amount>=500.0:
      self.balance -= amount
      self.printDetails()
    else:
      print("Withdraw unsuccessful. You do not have sufficient balance.")

acc1 = Account(1543563,"Alice",500000.0)
acc2 = Account(4242342,"Bob",30000.0)
acc1.printDetails()
print("1.---------------------------------------")
acc2.printDetails()
print("2.---------------------------------------")
acc1.deposit(50000.0)
print("3.---------------------------------------")
acc2.deposit(1000.0)
print("4.---------------------------------------")
acc1.withdraw(100000.0)
print("5.---------------------------------------")
acc2.withdraw(100000.0)
# Out:
# Account Number:1543563
# Account Name:Alice
# Current balance:500000.0 tk
# 1.---------------------------------------
# Account Number:4242342
# Account Name:Bob
# Current balance:30000.0 tk
# 2.---------------------------------------
# Account Number:1543563
# Account Name:Alice
# Current balance:550000.0 tk
# 3.---------------------------------------
# Account Number:4242342
# Account Name:Bob
# Current balance:31000.0 tk
# 4.---------------------------------------
# Account Number:1543563
# Account Name:Alice
# Current balance:450000.0 tk
# 5.---------------------------------------
# Withdraw unsuccessful. You do not have sufficient balance.

# %%
#OOP Class 3
#Example 2
class Student:
  def __init__(self,name,ID,dept):
    self.name = name
    self.ID = ID
    self.dept = dept
    self.courseList = []
    print(f"{self.name} has been created.")
  def printDetails(self):
    print(f"Name:{self.name}")
    print(f"ID:{self.ID}")
    print(f"Department:{self.dept}")
    print(f"{self.name} has taken {len(self.courseList)} course(s).")
    print("The courses are:")
    for i in self.courseList:
      print(i)
  def addCourse(self,*args): #Using *args as we don't know the exact number of arguments that will be passed
    for i in args:
      self.courseList.append(i)
  #Alternate approach
    #self.courseList.append(list(args))


s1 = Student("Bob",18301120,"CSE")
print("1.---------------------------------------")
s2 = Student("Alice",19023103,"CS")
print("2.---------------------------------------")
s1.addCourse("CSE111","PHY111","MAT110")
#If we want to set tough question
#s1.addCourse("CSE111",4.0,"PHY111",3.3,"MAT110",3.7) #Calculate GPA
#s1.addCourse("CSE111",93.5,"PHY111",78.0,"MAT110",86.2)#Calculate GPA
print("3.---------------------------------------")
s2.addCourse("CSE111","MAT120","CSE260","PHY112")
#If we want to set tough question
#s2.addCourse("CSE111",3.7,"MAT120",4.0,"CSE260",3.3,"PHY112",4.0) #Calculate GPA
#s2.addCourse("CSE111",88.3,"MAT120",95.1,"CSE260",77.5,"PHY112",94.3) #Calculate GPA
print("4.---------------------------------------")
s1.printDetails()
print("5.---------------------------------------")
s2.printDetails()
# Out:
# Bob has been created.
# 1.---------------------------------------
# Alice has been created.
# 2.---------------------------------------
# 3.---------------------------------------
# 4.---------------------------------------
# Name:Bob
# ID:18301120
# Department:CSE
# Bob has taken 3 course(s).
# The courses are:
# CSE111
# PHY111
# MAT110
# 5.---------------------------------------
# Name:Alice
# ID:19023103
# Department:CS
# Alice has taken 4 course(s).
# The courses are:
# CSE111
# MAT120
# CSE260
# PHY112

# %%
#OOP Class 5
#Practice 1
class Course:
  def __init__(self,title,code):
    self.title = title
    self.code = code
class Teacher:
  def __init__(self,name,des):
    self.name = name
    self.des = des
    self.cList = [] # w
  def addCourse(self,*args):
    for i in args:
      self.cList.append(i)
  def printDetails(self):
    print(f"Name:{self.name}")
    print(f"Designation:{self.des}")
    for i in self.cList:
      print(f"{i.code} - {i.title}") #p

c1 = Course("Programming Language I","CSE110")
c2 = Course("Programming Language II","CSE111")
c3 = Course("Digital Logic Design","CSE260")
c4 = Course("Discrete Mathematics","CSE230")
c5 = Course("Data Structure","CSE220")
t1 = Teacher("Alice","Lecturer")
t2 = Teacher("Bob","Assistant Prof")
t1.addCourse(c1,c2)
print("-------------------------------")
t1.printDetails()
print("-------------------------------")
t2.addCourse(c4,c5,c3)
print("-------------------------------")
t2.printDetails()
# Out:
# -------------------------------
# Name:Alice
# Designation:Lecturer
# CSE110 - Programming Language I
# CSE111 - Programming Language II
# -------------------------------
# -------------------------------
# Name:Bob
# Designation:Assistant Prof
# CSE230 - Discrete Mathematics
# CSE220 - Data Structure
# CSE260 - Digital Logic Design

# %%
#OOP Class 5
#Practice 2
class Library:
  def __init__(self,name):
    self.name = name
    self.bookCount=0
    self.bookList = {} #{"Programming":[Teach Yourself C,Teach Yourself C++]}
  def addBook(self,*args):#(COM)
    for i in args:
      self.bookCount+=1
      if i.cat not in self.bookList:
        self.bookList[i.cat] =[i.name]
      else:
        self.bookList[i.cat].append(i.name)
  def printDetails(self):
    print(f"Name:{self.name}")
    print(f"Number of books:{self.bookCount}")
    for k,v in self.bookList.items():
      print(f"{k} : {','.join(v)}")
class Book:
  def __init__(self,name,cat):
    self.name = name
    self.cat = cat    
l1 = Library("AYESHA ABED Library") #DHK
b1 = Book("Teach Yourself C","Programming") #RAJ
b2 = Book("Teach Yourself C++","Programming")#COM
b3 = Book("Angels and Demons","Fiction")#NOA
b4 = Book ("Discrete Mathematics","Mathematics")#SYL
b5 = Book ("Calculus","Mathematics")#CTG
l1.addBook(b1)
l1.addBook(b2)
l1.addBook(b3,b4,b5)
print("-------------------------------")
l1.printDetails()
# Out:
# -------------------------------
# Name:AYESHA ABED Library
# Number of books:5
# Programming : Teach Yourself C,Teach Yourself C++
# Fiction : Angels and Demons
# Mathematics : Discrete Mathematics,Calculus

# %%
class Book:
  def __init__(self, bn, c):
    self.bn = bn
    self.c = c
class Library:
  def __init__(self,n):
    self.n=n
    self.book={}
    self.bookcount=0
  def addBook(self,*args):
    print(args,"lll")
    for i in args:
      print(i,"ppp")
      self.bookcount+=1
      # if i.c not in self.book:
      if i.c in self.book:
        self.book[i.c].append(i.bn)
        # self.book[i.c]=[i.bn]
        print(i.c,"ok")
        print(i.bn,"damn")
      else:
        # self.book[i.c].append(i.bn)
        self.book[i.c]=[i.bn]
        print(i.c,"opppa")
        print(i.bn,"hehe")
  def printDetails(self):
    print(f"Name:{self.n}")
    print(f"Number of books:{self.bookcount}")
    for k,v in self.book.items():
      print(f"{k}:{','.join(v)}")
l1 = Library("AYESHA ABED Library") #DHK
b1 = Book("Teach Yourself C","Programming") #RAJ
b2 = Book("Teach Yourself C++","Programming")#COM
b3 = Book("Angels and Demons","Fiction")#NOA
b4 = Book ("Discrete Mathematics","Mathematics")#SYL
b5 = Book ("Calculus","Mathematics")#CTG
l1.addBook(b1)
l1.addBook(b2)
l1.addBook(b3,b4,b5)
print("-------------------------------")
l1.printDetails()
# Out:
# (<__main__.Book object at 0x7fc1898b8b90>,) lll
# <__main__.Book object at 0x7fc1898b8b90> ppp
# Programming opppa
# Teach Yourself C hehe
# (<__main__.Book object at 0x7fc1897e5150>,) lll
# <__main__.Book object at 0x7fc1897e5150> ppp
# Programming ok
# Teach Yourself C++ damn
# (<__main__.Book object at 0x7fc188fdba50>, <__main__.Book object at 0x7fc186f6fbd0>, <__main__.Book object at 0x7fc186f6fc10>) lll
# <__main__.Book object at 0x7fc188fdba50> ppp
# Fiction opppa
# Angels and Demons hehe
# <__main__.Book object at 0x7fc186f6fbd0> ppp
# Mathematics opppa
# Discrete Mathematics hehe
# <__main__.Book object at 0x7fc186f6fc10> ppp
# Mathematics ok
# Calculus damn
# -------------------------------
# Name:AYESHA ABED Library
# Number of books:5
# Programming:Teach Yourself C,Teach Yourself C++
# Fiction:Angels and Demons
# Mathematics:Discrete Mathematics,Calculus

# %%
#ungraded 20
class Student:
  def __init__(self,name=None,sub=None):
    self.name=name
    self.sub=sub
    self.x=[]
    self.count=0
    if self.name==None and self.sub==None:
      print("Student name and department need to be set")
    elif self.name!=None and self.sub==None:
      print(f"Department for {self.name} needs to be set")
    else:
      print(f"{self.name} is from {self.sub} department")
  def update_name(self,n):
    self.name=n
  def update_department(self,d):
    self.sub=d
  def enroll(self,*args):
    for i in args:
      self.count+=1
      self.x.append(i)
  def printDetail(self):
    print(f"Name:{self.name}")
    print(f"Department: {self.sub}")
    print(f"{self.name} enrolled in {self.count} course(s)")
s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name:Bob
# Department: CSE
# Bob enrolled in 3 course(s)
# ...
# Name:Carol
# Department: BBA
# Carol enrolled in 1 course(s)
# ...
# Name:Jon
# Department: EEE
# Jon enrolled in 2 course(s)

# %%
#ungraded21
class Student:
  def __init__(self,n,id,d):
    self.n=n
    self.id=id
    self.d=d
    self.p=[]
  def details(self):
    return f"Name: {self.n}\nId: {self.id}\nDepartment: {self.d}"
  def advise(self,*args):
    for i in args:
      self.p.append(i)
    print(f"{self.n} you have taken {len(args)*3.0} credits.")
#1stype
    print(f"List of courses: {','.join(self.p)}")

#2type    
    # print("List of courses: ",end="")
    # for i in range(len(self.p)):
    #   if i == int(len(self.p)-1):
    #     print(self.p[i])
    #   else:
    #     print(self.p[i],end=",")
#3rd type
    print("List of courses: ",end="")
    s=""
    for i in args:
      s+=i+","
    print(s[:-1])

    if len(args)>4:
      print("Status: You have to drop at least 1 course")
    elif len(args)<3:
      print("Status: You have to take at least 1 more course.")
    else:
      print("Status: Ok")
s1 = Student("Alice","20103012","CSE")
s2 = Student("Bob", "18301254","EEE")
s3 = Student("Carol", "17101238","CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110", "MAT110", "PHY111")
print("##########################")
s2.advise("BUS101", "MAT120")
print("##########################")
s3.advise("MAT110", "PHY111", "ENG102","CSE111", "CSE230")
# Out:
# ##########################
# Name: Alice
# Id: 20103012
# Department: CSE
# ##########################
# Name: Bob
# Id: 18301254
# Department: EEE
# ##########################
# Alice you have taken 9.0 credits.
# List of courses: CSE110,MAT110,PHY111
# Status: Ok
# ##########################
# Bob you have taken 6.0 credits.
# List of courses: BUS101,MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Carol you have taken 15.0 credits.
# List of courses: MAT110,PHY111,ENG102,CSE111,CSE230
# Status: You have to drop at least 1 course

# %%
#ungraded 23
class Author:
  def __init__(self,name=None):
    self.name=name
    self.a={}
    # self.xD=[]
    # self.hehe=[]
    self.count=0
  def addBook(self,b,c):
    self.b=b
    self.c=c
    # for i in b:
    #   self.xD.append(i)
    #   self.count += 1
    # for i in c:
    #   self.hehe.append(i)
    if self.name==None:
      print("A book can not be added without author name")
    else:
      # pass
        if self.c not in self.a:
          self.a[self.c]=[self.b]
        else:
          self.a[self.c].append(self.b)
        self.count+=1
        # if c not in self.a:
        #   self.a[c]=[b]
        # else:
        #   self.a[c].append(b)
        # self.count+=1
  def setName(self,name):
    self.name=name
  def printDetail(self):
    print(f"Number of Books(s): {self.count}")
    print(f"Author Name: {self.name}")
    for k,v in self.a.items():
      print(f"{k}: {','.join(v)}")
    # print(self.a)
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Books(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# ...
# Number of Books(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# ...
# Number of Books(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon,Ireena
# Horror: Megher Upor Bari
# ...

# %%
class TaxiLagbe:
    def __init__(self,number,name):
        self.number=number
        self.name=name
        self.p=[]
        self.k=[]
    def addPassenger(self,*args):
        if len(self.p)<4:
            for i in args:
                a,b=i.split("_")
                self.p.append(a)
                self.k.append(int(b))
        else:
            print("Taxi Full! No more passengers can be added.")

    # def addPassenger(self,*p_n): Extraaaaaaaaa
    #     self.p_n=list(p_n)
    #     # self.x=",".join(self.p_n)
    #     # self.ok=self.x.split(",")
    #     # print(self.ok,"LLL")
    #     # print(self.p_n)
    #     # print(self.x,"l")
    #     for i in range(len(self.p_n)):
    #         if i>4:
    #             print("Taxi Full! No more passengers can be added.")
    #
    #         else:
    #             self.p.append(p_n[i])
    #     # for i in self.p:
    #     #     self.k.append(i)
    #     # print(self.p)"""

    def printDetails(self):
        print(f"Trip info for Taxi number: {self.number}")
        print(f"This taxi can cover only {self.name} area.")
        print(f"Total passengers:{len(self.p)}")
        print(f"Passenger lists:")
        for i in range(len(self.p)):
            if i==len(self.p)-1:
                print(self.p[i])
            else:
                print(self.p[i],end=",")

        print(f"Total collected fare: {str(sum(self.k))}")
taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200')
taxi1.addPassenger('Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115')
taxi2.addPassenger('Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger lists:
# Walker,Wood,Matt,Wilson
# Total collected fare: 505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger lists:
# Walker,Wood,Matt,Wilson
# Total collected fare: 505
# -------------------------------
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers:2
# Passenger lists:
# Ronald,Parker
# Total collected fare: 330

# %%
class Customer:
    def __init__(self,name):
        self.name=name
        self.x=[]
        self.l=0
        # print(self.name)
    def greet(self,o=''):
        self.o=o
        if self.o!="":
            print(f"Hello {''.join(self.o)}!")
        else:
            print("Hello!")
    def purchase(self,*p):
        for i in p:
            self.x.append(i)
            self.l+=1
        print(f"{self.name}, you purchased {self.l} item(s):")
        for i in self.x:
            print(i)
customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchased 3 item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David, you purchased 1 item(s):
# orange juice

# %%
class Student:
  def __init__(self,name,ID,dept):
    self.name = name
    self.ID = ID
    self.dept = dept
    self.courseList = []
    print(f"{self.name} has been created.")
  def printDetails(self):
    self.k = []
    self.l = []
    for i in range(len(self.courseList)):
      if i % 2 == 0:
        self.k.append(self.courseList[i])
      else:
        self.l.append(self.courseList[i])
    print(f"Name:{self.name}")
    print(f"ID:{self.ID}")
    print(f"Department:{self.dept}")
    print(f"{self.name} has taken {len(self.courseList)//2} course(s).")
    print("The courses are:")
    for i in self.k:
      print(i)
    p,q=0,0
    # z=p/q
    for i in self.l:
      p+=i
      q+=1
    z = p / q
    print(f"cgpa:{z}")

  def addCourse(self,*args): #Using *args as we don't know the exact number of arguments that will be passed
    for i in args:
      self.courseList.append(i)
#
#
s1 = Student("Bob",18301120,"CSE")
print("1.---------------------------------------")
s2 = Student("Alice",19023103,"CS")
print("2.---------------------------------------")
s1.addCourse("CSE111",4.0,"PHY111",3.3,"MAT110",3.7)
# s1.addCourse("CSE111","PHY111","MAT110")
# print("3.---------------------------------------")
# s2.addCourse("CSE111","MAT120","CSE260","PHY112")
s2.addCourse("CSE111",3.7,"MAT120",4.0,"CSE260",3.3,"PHY112",4.0)
# print("4.---------------------------------------")
s1.printDetails()
# print("5.---------------------------------------")
s2.printDetails()
# Out:
# Bob has been created.
# 1.---------------------------------------
# Alice has been created.
# 2.---------------------------------------
# Name:Bob
# ID:18301120
# Department:CSE
# Bob has taken 3 course(s).
# The courses are:
# CSE111
# PHY111
# MAT110
# cgpa:3.6666666666666665
# Name:Alice
# ID:19023103
# Department:CS
# Alice has taken 4 course(s).
# The courses are:
# CSE111
# MAT120
# CSE260
# PHY112
# cgpa:3.75

# %%
# class Student:
#     def __init__(self,n,i,d):
#         self.n=n
#         self.i=i
#         self.d=d
#         print(f"{self.n} has been created.")
#     def addCourse(self,*c):
#         self.c=c
#     def printDetails(self):
#         print("Name",self.n)
#         print("ID",self.i)
#         print("Department:",self.d)
#         print("The courses are:")
#         print("Course count",(len(self.c)))
#         for i in self.c:
#             print(i)
class Student:
  def __init__(self,name,ID,dept):
    self.name = name
    self.ID = ID
    self.dept = dept
    self.courseList = []
    print(f"{self.name} has been created.")
  def printDetails(self):
    self.k = []
    self.l = []
    for i in range(len(self.courseList)):
      if i % 2 == 0:
        self.k.append(self.courseList[i])
      else:
        self.l.append(self.courseList[i])
    print(f"Name:{self.name}")
    print(f"ID:{self.ID}")
    print(f"Department:{self.dept}")
    print(f"{self.name} has taken {len(self.courseList)//2} course(s).")
    print("The courses are:")
    for i in self.k:
      print(i)
    p,q=0,0
    # z=p/q
    for i in self.l:
      p+=i
      q+=1
    z = p / q
    ok=float(z)
    oks=round(ok,2)
    print(f"cgpa:{oks}")

  def addCourse(self,*args): #Using *args as we don't know the exact number of arguments that will be passed
    for i in args:
      self.courseList.append(i)
#
#
s1 = Student("Bob",18301120,"CSE")
print("1.---------------------------------------")
s2 = Student("Alice",19023103,"CS")
print("2.---------------------------------------")
s1.addCourse("CSE111",4.0,"PHY111",3.3,"MAT110",3.7)
# s1.addCourse("CSE111","PHY111","MAT110")
print("3.---------------------------------------")
# s2.addCourse("CSE111","MAT120","CSE260","PHY112")
s2.addCourse("CSE111",3.7,"MAT120",4.0,"CSE260",3.3,"PHY112",4.0)
print("4.---------------------------------------")
s1.printDetails()
print("5.---------------------------------------")
s2.printDetails()
# Out:
# Bob has been created.
# 1.---------------------------------------
# Alice has been created.
# 2.---------------------------------------
# 3.---------------------------------------
# 4.---------------------------------------
# Name:Bob
# ID:18301120
# Department:CSE
# Bob has taken 3 course(s).
# The courses are:
# CSE111
# PHY111
# MAT110
# cgpa:3.67
# 5.---------------------------------------
# Name:Alice
# ID:19023103
# Department:CS
# Alice has taken 4 course(s).
# The courses are:
# CSE111
# MAT120
# CSE260
# PHY112
# cgpa:3.75

# %%
#quizz
#Set A
class Bus:
    def __init__(self,name,route):
        self.name = name
        self.route = route
        self.current_location = "Gabtoli" #Will be used to store where the bus is right now and from where the passengers are getting on the bus.
        self.pList = {}#Will be used to store the passenger list
        self.fare = 0#Will be used to calculate collected fare.
        self.pCount=0#Will be used to count the number of passengers.
        print(f"{self.name} is currently at {self.current_location}")
    def addPassenger(self,*args):
        for i in range(0,len(args),2):
            if args[i+1] not in bus_fare:#Check if the destination is available in bus_fare dictionary.
                print(f"Sorry {args[i]}, this bus does not go to {args[i+1]}.")
            else:
                #the fares given in bus_fare dictionary is from Gabtoli. So if the passenger gets on bus from Shyamoli, his/her fare should be (Fare of desnation - Fare of Shyamoli).
                self.fare += bus_fare[args[i+1]]-bus_fare[self.current_location]
                self.pCount+=1#Passenger count will increase.
                print(f"{args[i]} please get on the bus.")
                #'current_location' variable holds the source of the passenger and args[i+1] holds the destination of the passenger.
                #Used a tuple as a key to store the source and destination of a passenger together.
                if (self.current_location,args[i+1]) not in self.pList:
                    self.pList[(self.current_location,args[i+1])]= [args[i]]
                else:
                    self.pList[(self.current_location,args[i+1])].append(args[i])
    def printDetails(self):
        print(f"Bus Name:{self.name}")
        print(f"Route:{self.route}")
        print(f"Total passengers: {self.pCount}")
        print(f"Total fare collected:{self.fare} taka.")
        print("Passenger List:")
        for k,v in self.pList.items():
            print(f"{k[0]} To {k[1]}: {', '.join(v)}")
    
    def reach(self,des): 
        #Whenever the bus reaches a destination the source of the passengers need to be updated.
        #For example if the bus reaches Shyamoli, all the passengers who will get on the bus now are from Shyamoli.
        #This will help us to calculate the fare of the passengers.
        self.current_location = des 
        print(f"Reached {des}.")
        #If the bus reaches Shyamoli, all the passengers whose distination was Shyamoli needs to get down.
        #So we need to delete those passengers from our pList dictionary.
        x = self.pList.copy()#We cannot change the size of the dictionary while iterating on it.So we will run iteration on a copy of the dictionary.
        for k,v in x.items():
            if des == k[1]:
                print(f"{', '.join(self.pList[k])} please get down.")
                self.pCount-=len(self.pList[k])#If passengers get down, total passenger count will decrease.
                del(self.pList[k])#Delete the passengers whose destination have been reached.
        
                
        
bus_fare={"Gabtoli":0,"Shyamoli":10,"Dhanmondi 27":15} 
bus_fare["Science Lab"]=20
bus_fare["Shahabag"] = 25
bus_fare["Motsho bhaban"] = 30
bus_fare["Stadium"] = 35
print("1.--------------------------------")
b1 = Bus("7 no bus", "Gabtoli-Gulistan")
print("2.--------------------------------")
b1.addPassenger("Alice","Science Lab","Bob","Dhanmondi 27")
print("3.--------------------------------")
b1.addPassenger("Jack","Stadium","Aeron","Shyamoli")
print("4.--------------------------------")
b1.printDetails()
print("5.--------------------------------")
b1.addPassenger("Robin","New Market")
print("6.--------------------------------")
b1.reach("Shyamoli")
print("7.--------------------------------")
b1.addPassenger("Jon","Stadium","Beck","Shahabag")
print("8.--------------------------------")
b1.printDetails()
print("9.--------------------------------")
b1.reach("Dhanmondi 27")
print("10.--------------------------------")
b1.addPassenger("Ethan","Stadium")
print("11.--------------------------------")
b1.printDetails()
# Out:
# 1.--------------------------------
# 7 no bus is currently at Gabtoli
# 2.--------------------------------
# Alice please get on the bus.
# Bob please get on the bus.
# 3.--------------------------------
# Jack please get on the bus.
# Aeron please get on the bus.
# 4.--------------------------------
# Bus Name:7 no bus
# Route:Gabtoli-Gulistan
# Total passengers: 4
# Total fare collected:80 taka.
# Passenger List:
# Gabtoli To Science Lab: Alice
# Gabtoli To Dhanmondi 27: Bob
# Gabtoli To Stadium: Jack
# Gabtoli To Shyamoli: Aeron
# 5.--------------------------------
# Sorry Robin, this bus does not go to New Market.
# 6.--------------------------------
# Reached Shyamoli.
# Aeron please get down.
# 7.--------------------------------
# Jon please get on the bus.
# Beck please get on the bus.
# 8.--------------------------------
# Bus Name:7 no bus
# Route:Gabtoli-Gulistan
# Total passengers: 5
# Total fare collected:120 taka.
# Passenger List:
# Gabtoli To Science Lab: Alice
# ...

# %%
bus_fare={"Gabtoli":0,"Shyamoli":10,"Dhanmondi 27":15} 
bus_fare["Science Lab"]=20
bus_fare["Shahabag"] = 25
bus_fare["Motsho bhaban"] = 30
bus_fare["Stadium"] = 35
for k,v in bus_fare.items():
  print(k,"xD",v)
# Out:
# Gabtoli xD 0
# Shyamoli xD 10
# Dhanmondi 27 xD 15
# Science Lab xD 20
# Shahabag xD 25
# Motsho bhaban xD 30
# Stadium xD 35

# %%
#ungraded 22
class Hotel:
  def __init__(self,add):
    self.add=add
    self.nmr=0
  def addStuff(self,n,age,pp=000):
    self.n=n
    self.age=age
    self.pp=pp
  def getStuffById(self,nm):
    self.nm=nm
    return f"Staff With ID {self.nm} is added"
  def addGuest(self,na,ag,pn):
    self.na=na
    self.ag=ag
    self.pn=pn
  def getGuestById(self,pl):
    self.pl=pl ## change korte hobe
    self.nmr+=1
    return f"Guest with ID {self.pl} is created"
  def allStaffs(self):
    print("All Staffs:")
    print(f"Number of Staff:{self.nm}")
    print(f"Staff Id:{self.nm} Name:{self.n} Age:{self.age} Phone no:{self.pp} ")
  def allGuest(self):
    print("All Guest:")
    print(f"Number of Guest:{self.nmr}")
    print(f"guest Id:{self.pl} Name:{self.na} Age:{self.ag} Phone no:{self.pn} ")
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,"123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# ...
# Staff With ID 1 is added
# ...
# Guest with ID 1 is created
# ...
# Guest with ID 2 is created
# ...
# All Staffs:
# Number of Staff:1
# Staff Id:1 Name:Adam Age:26 Phone no:0
# ...
# All Guest:
# Number of Guest:2
# guest Id:2 Name:Diana Age:32 Phone no:431

# %%
class Hotel:
  def __init__(self,add):
    self.add=add
    self.nmr=0
    self.staff=0
    self.guest=0
    self.a={}
    self.b={}
  def addStuff(self,n,age,pp=000):
    self.n=n
    self.age=age
    self.pp=pp
    for i in self.a:
        self.a[self.staff]=[self.n,self.age,self.pp]
    print(self.a)
    self.staff+=1
    print (f"Staff With ID {self.a} is added")
  def getStuffById(self,staff):
    # self.staff=staff
    for i in self.a:
        if self.a.keys()==staff:
            print(f"Staff ID:{staff}\nName:{self.n}\nAge:{self.age}\nPhone no:{self.pp}")
        else:
            continue
    # return f"Staff With ID {self.nm} is added"
  def addGuest(self,na,ag,pn):
    self.na=na
    self.ag=ag
    self.pn=pn
    for i in self.b:
        self.b[self.guest]=[self.na,self.ag,self.pn]
    self.guest+=1
    print (f"guest With ID {self.b} is added")
  def getGuestById(self,guest):
    # self.pl=pl ## change korte hobe
    for i in self.b:
        if self.b.keys()==guest:
            print(f"Staff ID:{guest}\nName:{self.na}\nAge:{self.ag}\nPhone no:{self.pn}")
        else:
            continue
  def allStaffs(self):
    print("All Staffs:")
    print(f"Number of Staff:{self.staff}")
    print(f"Staff Id:{self.staff} Name:{self.n} Age:{self.age} Phone no:{self.pp} ")
  def allGuest(self):
    print("All Guest:")
    print(f"Number of Guest:{self.nmr}")
    for k in self.b.keys():
        print(f"guest Id:{k}",end="")
    for v in self.b:
        print(f" Name:{self.na} Age:{self.ag} Phone no:{self.pn} ")
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,"123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# {}
# Staff With ID {} is added
# ...
# None
# ...
# guest With ID {} is added
# ...
# None
# ...
# guest With ID {} is added
# ...
# None
# ...
# All Staffs:
# Number of Staff:1
# Staff Id:1 Name:Adam Age:26 Phone no:0
# ...
# All Guest:
# Number of Guest:0

# %%
#un 25
class Vaccine:
  def __init__ (self, name, made_in, interval):
    self.name=name
    self.made_in=made_in
    self.interval=interval

class Person:
  def __init__ (self, pname, age, ptype= "General Citizen"):
    self.pname=pname
    self.age=age
    self.ptype=ptype
    self.vac=""
    self.firstdose= False
    self.secdose= False
  def pushVaccine(self, vacN, dose= "ist dose"):
    if dose== "1st dose":
      if self.age >=25 or self.ptype == "Student":
        self.vac = vacN
        self.firstdose= True
        print("1st dose done for", self.pname)
      else:
        print("Sorry", self.pname, "Minimum age for taking vaccines is 25 years now.")
    else:
      if self.vac.name != vacN.name:
        print("Sorry", self.pname, "you can’t take 2 different vaccines.")
      elif self.firstdose== True:
        self.secdose=True
        print("2nd dose done for", self.pname)
  def showDetail (self):
    print("Name:", self.pname, "Age:", self.age, "Type:", self.ptype)
    print("Vaccine name:", self.vac.name)
    if self.secdose == True:
      print("1st dose given")
      print("2nd dose given")
    elif self.firstdose== True:
      print("1st dose given")
      print("2nd dose: Please come after", self.vac.interval, "days" )


astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-319ecdef2241> in <module>()
#      44 p1 = Person("Bob", 21, "Student")
#      45 print("=================================")
# ---> 46 p1.pushVaccine(astra)
#      47 print("=================================")
#      48 p1.showDetail()
#
# <ipython-input-11-319ecdef2241> in pushVaccine(self, vacN, dose)
#      23         print("Sorry", self.pname, "Minimum age for taking vaccines is 25 years now.")
#      24     else:
# ---> 25       if self.vac.name != vacN.name:
#      26         print("Sorry", self.pname, "you can’t take 2 different vaccines.")
#      27       elif self.firstdose== True:
#
# AttributeError: 'str' object has no attribute 'name'

# %%
#un 24
class Hospital:
    def __init__(self,name):
        self.name=name
        self.ddict={}
        self.pdict={}
    def addDoctor(self,doc):
        self.ddict[doc.ID]=[doc.name,doc.specialist]
    def getDoctorByID(self,ID):
        return f"Doctor's ID:{ID}\nName:{self.ddict[ID][0]}\nSpeciality:{self.ddict[ID][1]}"
    def addPatient(self,patient):
        self.pdict[patient.ID] = [patient.name, patient.age,patient.phone]
    def getPatientByID(self,ID):
        return f"Patients's ID:{ID}\nPatient Name:{self.pdict[ID][0]}\nPatient Age: {self.pdict[ID][1]}"
    def allDoctors(self):
        print("All Doctors:")
        print("Number of doctors:",len(self.ddict))
        print(self.ddict)
    def allPatients(self):
        print("All Patients:")
        print("Number of patients:",len(self.pdict))
        print(self.pdict)
class Doctor:
    def __init__(self,ID,prof,name,specialist):
        self.ID=ID
        self.prof=prof
        self.name=name
        self.specialist=specialist
class Patient:
    def __init__(self,ID,prof,name,age,phone):
        self.ID=ID
        self.prof=prof
        self.name=name
        self.age=age
        self.phone=phone
h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# Out:
# ...
# Doctor's ID:1d
# Name:Samar Kumar
# Speciality:Neurologist
# ...
# Patients's ID:1p
# Patient Name:Kashem Ahmed
# Patient Age: 35
# ...
# Patients's ID:2p
# Patient Name:Tanina Haque
# Patient Age: 26
# ...
# All Doctors:
# Number of doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Number of patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}
